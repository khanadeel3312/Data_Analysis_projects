# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
d_a=pd.read_csv('dailyActivity_merged.csv')
s_d=pd.read_csv('sleepDay_merged.csv')
w_l=pd.read_csv('weightLogInfo_merged.csv')

# %%
from matplotlib.pyplot import figure 
plt.style.use('ggplot')
# %matplotlib inline

# %%
w_l.head()
# Out:
#            Id                   Date    WeightKg  WeightPounds   Fat  \
# 0  1503960366   5/2/2016 11:59:59 PM   52.599998    115.963147  22.0
# 1  1503960366   5/3/2016 11:59:59 PM   52.599998    115.963147   NaN
# 2  1927972279   4/13/2016 1:08:52 AM  133.500000    294.317120   NaN
# 3  2873212765  4/21/2016 11:59:59 PM   56.700001    125.002104   NaN
# 4  2873212765  5/12/2016 11:59:59 PM   57.299999    126.324875   NaN
#
#          BMI  IsManualReport          LogId
# 0  22.650000            True  1462233599000
# 1  22.650000            True  1462319999000
# 2  47.540001           False  1460509732000
# 3  21.450001            True  1461283199000
# 4  21.690001            True  1463097599000

# %%
s_d
# Out:
#              Id               SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0    1503960366  4/12/2016 12:00:00 AM                  1                 327
# 1    1503960366  4/13/2016 12:00:00 AM                  2                 384
# 2    1503960366  4/15/2016 12:00:00 AM                  1                 412
# 3    1503960366  4/16/2016 12:00:00 AM                  2                 340
# 4    1503960366  4/17/2016 12:00:00 AM                  1                 700
# ..          ...                    ...                ...                 ...
# 408  8792009665  4/30/2016 12:00:00 AM                  1                 343
# 409  8792009665   5/1/2016 12:00:00 AM                  1                 503
# 410  8792009665   5/2/2016 12:00:00 AM                  1                 415
# 411  8792009665   5/3/2016 12:00:00 AM                  1                 516
# 412  8792009665   5/4/2016 12:00:00 AM                  1                 439
#
#      TotalTimeInBed
# ...

# %%
d_a.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    4/12/2016       13162           8.50             8.50
# 1  1503960366    4/13/2016       10735           6.97             6.97
# 2  1503960366    4/14/2016       10460           6.74             6.74
# 3  1503960366    4/15/2016        9762           6.28             6.28
# 4  1503960366    4/16/2016       12669           8.16             8.16
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.57                      0.69
# 2                       0.0                2.44                      0.40
# 3                       0.0                2.14                      1.26
# 4                       0.0                2.71                      0.41
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
d_a.drop_duplicates()
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    4/12/2016       13162       8.500000         8.500000
# 1    1503960366    4/13/2016       10735       6.970000         6.970000
# 2    1503960366    4/14/2016       10460       6.740000         6.740000
# 3    1503960366    4/15/2016        9762       6.280000         6.280000
# 4    1503960366    4/16/2016       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391     5/8/2016       10686       8.110000         8.110000
# 936  8877689391     5/9/2016       20226      18.250000        18.250000
# 937  8877689391    5/10/2016       10733       8.150000         8.150000
# 938  8877689391    5/11/2016       21420      19.559999        19.559999
# 939  8877689391    5/12/2016        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
w_l.drop_duplicates()
# Out:
#             Id                   Date    WeightKg  WeightPounds   Fat  \
# 0   1503960366   5/2/2016 11:59:59 PM   52.599998    115.963147  22.0
# 1   1503960366   5/3/2016 11:59:59 PM   52.599998    115.963147   NaN
# 2   1927972279   4/13/2016 1:08:52 AM  133.500000    294.317120   NaN
# 3   2873212765  4/21/2016 11:59:59 PM   56.700001    125.002104   NaN
# 4   2873212765  5/12/2016 11:59:59 PM   57.299999    126.324875   NaN
# ..         ...                    ...         ...           ...   ...
# 62  8877689391    5/6/2016 6:43:35 AM   85.000000    187.392923   NaN
# 63  8877689391    5/8/2016 7:35:53 AM   85.400002    188.274775   NaN
# 64  8877689391    5/9/2016 6:39:44 AM   85.500000    188.495234   NaN
# 65  8877689391   5/11/2016 6:51:47 AM   85.400002    188.274775   NaN
# 66  8877689391   5/12/2016 6:42:53 AM   84.000000    185.188300   NaN
#
#           BMI  IsManualReport          LogId
# 0   22.650000            True  1462233599000
# ...

# %%
s_d.drop_duplicates()
# Out:
#              Id               SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0    1503960366  4/12/2016 12:00:00 AM                  1                 327
# 1    1503960366  4/13/2016 12:00:00 AM                  2                 384
# 2    1503960366  4/15/2016 12:00:00 AM                  1                 412
# 3    1503960366  4/16/2016 12:00:00 AM                  2                 340
# 4    1503960366  4/17/2016 12:00:00 AM                  1                 700
# ..          ...                    ...                ...                 ...
# 408  8792009665  4/30/2016 12:00:00 AM                  1                 343
# 409  8792009665   5/1/2016 12:00:00 AM                  1                 503
# 410  8792009665   5/2/2016 12:00:00 AM                  1                 415
# 411  8792009665   5/3/2016 12:00:00 AM                  1                 516
# 412  8792009665   5/4/2016 12:00:00 AM                  1                 439
#
#      TotalTimeInBed
# ...

# %%
d_a.isnull().sum()
# Out:
# Id                          0
# ActivityDate                0
# TotalSteps                  0
# TotalDistance               0
# TrackerDistance             0
# LoggedActivitiesDistance    0
# VeryActiveDistance          0
# ModeratelyActiveDistance    0
# LightActiveDistance         0
# SedentaryActiveDistance     0
# VeryActiveMinutes           0
# FairlyActiveMinutes         0
# LightlyActiveMinutes        0
# SedentaryMinutes            0
# Calories                    0
# dtype: int64

# %%
s_d.isnull().sum()
# Out:
# Id                    0
# SleepDay              0
# TotalSleepRecords     0
# TotalMinutesAsleep    0
# TotalTimeInBed        0
# dtype: int64

# %%
w_l.isnull().sum()
# Out:
# Id                 0
# Date               0
# WeightKg           0
# WeightPounds       0
# Fat               65
# BMI                0
# IsManualReport     0
# LogId              0
# dtype: int64

# %%
w_l.describe()
# Out:
#                  Id    WeightKg  WeightPounds       Fat        BMI  \
# count  6.700000e+01   67.000000     67.000000   2.00000  67.000000
# mean   7.009282e+09   72.035821    158.811801  23.50000  25.185224
# std    1.950322e+09   13.923206     30.695415   2.12132   3.066963
# min    1.503960e+09   52.599998    115.963147  22.00000  21.450001
# 25%    6.962181e+09   61.400002    135.363832  22.75000  23.959999
# 50%    6.962181e+09   62.500000    137.788914  23.50000  24.389999
# 75%    8.877689e+09   85.049999    187.503152  24.25000  25.559999
# max    8.877689e+09  133.500000    294.317120  25.00000  47.540001
#
#               LogId
# count  6.700000e+01
# mean   1.461772e+12
# std    7.829948e+08
# min    1.460444e+12
# 25%    1.461079e+12
# 50%    1.461802e+12
# 75%    1.462375e+12
# max    1.463098e+12

# %%
w_l.fillna(w_l.mean(),inplace=True)
# Out:
# C:\Users\Adeel Khan\AppData\Local\Temp\ipykernel_6304\2044823869.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   w_l.fillna(w_l.mean(),inplace=True)

# %%
d_a['ActivityDate']=pd.to_datetime(d_a['ActivityDate'])
Date=d_a['ActivityDate'].dt.date
d_a.drop(columns=['ActivityDate'],inplace=True)

d_a.insert(1,'Date1',Date)

# %%
s_d['SleepDay']=pd.to_datetime(s_d['SleepDay'])
Date=s_d['SleepDay'].dt.date
s_d.drop(columns=['SleepDay'],inplace =True)
s_d.insert(1,'Date1',Date)

# %%
w_l['Date']=pd.to_datetime(w_l['Date'])
date=w_l['Date'].dt.date

w_l.drop(columns=['Date'],inplace=True)
w_l.insert(1,'Date1',date)

# %%
merged1= pd.merge(s_d, d_a, on=['Id', 'Date1'], how='right')
merged=pd.merge(merged1,w_l,on=['Id', 'Date1'], how='right')
merged
# Out:
#             Id       Date1  TotalSleepRecords  TotalMinutesAsleep  \
# 0   1503960366  2016-05-02                1.0               277.0
# 1   1503960366  2016-05-03                1.0               273.0
# 2   1927972279  2016-04-13                1.0               398.0
# 3   2873212765  2016-04-21                NaN                 NaN
# 4   2873212765  2016-05-12                NaN                 NaN
# ..         ...         ...                ...                 ...
# 62  8877689391  2016-05-06                NaN                 NaN
# 63  8877689391  2016-05-08                NaN                 NaN
# 64  8877689391  2016-05-09                NaN                 NaN
# 65  8877689391  2016-05-11                NaN                 NaN
# 66  8877689391  2016-05-12                NaN                 NaN
#
#     TotalTimeInBed  TotalSteps  TotalDistance  TrackerDistance  \
# 0            309.0       14727       9.710000         9.710000
# ...

# %%
conditions = [
    (merged['BMI'] >= 30),
    (merged['BMI'] >= 25),
    (merged['BMI'] < 25)
]
choices = ['Obese', 'Healthy', 'Underweight']

merged['BMIRange'] = np.select(conditions, choices, default='Unknown')

# %%
merged['Date1'] = pd.to_datetime(merged['Date1'])
merged['Weekday']=merged['Date1'].dt.strftime('%A')
merged['Weekday']
# Out:
# 0        Monday
# 1       Tuesday
# 2     Wednesday
# 3      Thursday
# 4      Thursday
#         ...
# 62       Friday
# 63       Sunday
# 64       Monday
# 65    Wednesday
# 66     Thursday
# Name: Weekday, Length: 67, dtype: object

# %%
selected=['Id', 'Date1','TotalSleepRecords', 'TotalMinutesAsleep', 'TotalTimeInBed', 'TotalSteps', 'TotalDistance','VeryActiveMinutes', 'FairlyActiveMinutes', 'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories', 'WeightKg', 'BMI', 'Weekday']
merged1=merged[selected]
merged1
# Out:
#             Id      Date1  TotalSleepRecords  TotalMinutesAsleep  \
# 0   1503960366 2016-05-02                1.0               277.0
# 1   1503960366 2016-05-03                1.0               273.0
# 2   1927972279 2016-04-13                1.0               398.0
# 3   2873212765 2016-04-21                NaN                 NaN
# 4   2873212765 2016-05-12                NaN                 NaN
# ..         ...        ...                ...                 ...
# 62  8877689391 2016-05-06                NaN                 NaN
# 63  8877689391 2016-05-08                NaN                 NaN
# 64  8877689391 2016-05-09                NaN                 NaN
# 65  8877689391 2016-05-11                NaN                 NaN
# 66  8877689391 2016-05-12                NaN                 NaN
#
#     TotalTimeInBed  TotalSteps  TotalDistance  VeryActiveMinutes  \
# 0            309.0       14727       9.710000                 41
# ...

# %%
result = (
    merged1.groupby('Weekday')
    .agg({'TotalSteps': 'mean', 'Calories': 'mean'})
    .sort_values(by='Weekday')
    .reset_index()
    .rename(columns={'TotalSteps': 'MeanTotalSteps', 'Calories': 'MeanCalories'})
   
)
result
# Out:
#      Weekday  MeanTotalSteps  MeanCalories
# 0     Friday    10736.333333   2443.166667
# 1     Monday    12136.333333   2450.583333
# 2   Saturday    16916.428571   3075.571429
# 3     Sunday     7879.400000   2392.700000
# 4   Thursday    10909.909091   2234.818182
# 5    Tuesday    14165.666667   2637.444444
# 6  Wednesday    13006.750000   2721.833333

# %%
merged1['AwakeTimeInBed']=merged1['TotalTimeInBed']-merged1['TotalMinutesAsleep']
merged1['AwakeTimeInBed']
# Out:
# C:\Users\Adeel Khan\AppData\Local\Temp\ipykernel_6304\869130369.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged1['AwakeTimeInBed']=merged1['TotalTimeInBed']-merged1['TotalMinutesAsleep']
# 0     32.0
# 1     23.0
# 2     24.0
# 3      NaN
# 4      NaN
#       ...
# 62     NaN
# 63     NaN
# 64     NaN
# 65     NaN
# 66     NaN
# Name: AwakeTimeInBed, Length: 67, dtype: float64

# %%
result = (
    merged1.groupby('Weekday')
    .agg({'TotalMinutesAsleep': 'mean', 'TotalTimeInBed': 'mean','TotalTimeInBed':'mean','AwakeTimeInBed':'mean'})
    .reset_index())
    
   
 
result
# Out:
#      Weekday  TotalMinutesAsleep  TotalTimeInBed  AwakeTimeInBed
# 0     Friday          417.750000      432.500000       14.750000
# 1     Monday          414.800000      432.200000       17.400000
# 2   Saturday          401.250000      417.500000       16.250000
# 3     Sunday          425.666667      444.500000       18.833333
# 4   Thursday          476.400000      494.200000       17.800000
# 5    Tuesday          395.600000      423.400000       27.800000
# 6  Wednesday          465.833333      487.833333       22.000000

# %%
activity=(
    merged.groupby('Id')
    .agg({'VeryActiveMinutes':'mean','FairlyActiveMinutes':'mean','LightlyActiveMinutes':'mean','SedentaryMinutes':'mean'})
    .reset_index())
activity
# Out:
#            Id  VeryActiveMinutes  FairlyActiveMinutes  LightlyActiveMinutes  \
# 0  1503960366          45.500000            19.500000            265.500000
# 1  1927972279           0.000000             0.000000             32.000000
# 2  2873212765           1.000000             5.000000            319.500000
# 3  4319703577           4.000000             6.500000            158.000000
# 4  4558609924           7.600000            11.000000            316.600000
# 5  5577150313         200.000000            37.000000            159.000000
# 6  6962181067          22.366667            18.900000            245.533333
# 7  8877689391          68.041667             9.833333            236.000000
#
#    SedentaryMinutes
# 0        807.000000
# 1        986.000000
# 2        888.500000
# 3       1234.500000
# 4       1063.200000
# 5        525.000000
# 6        661.733333
# 7       1104.916667

# %%
plt.scatter(x=merged['TotalSteps'],y=merged['Calories'])

# %%
plt.scatter(merged['TotalSteps'], merged['Calories'], c=merged['Calories'], cmap='viridis')
plt.xlabel("Steps Taken")
plt.ylabel("Calories Burned")
plt.title("Calories Burned for Every Step Taken")
cbar = plt.colorbar()
cbar.set_label('Calories', rotation=90)

# %%
plt.bar(merged['Weekday'],merged['TotalSteps'])
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Monday'),
#   Text(1, 0, 'Tuesday'),
#   Text(2, 0, 'Wednesday'),
#   Text(3, 0, 'Thursday'),
#   Text(4, 0, 'Sunday'),
#   Text(5, 0, 'Friday'),
#   Text(6, 0, 'Saturday')])

# %%
avgsteps=merged['TotalSteps'].mean()
avgsteps
# Out:
# 12102.149253731342

# %%
plt.scatter(merged1['TotalMinutesAsleep'], merged1['TotalTimeInBed'], c=merged1['TotalTimeInBed'], cmap='viridis')

# Set labels and title
plt.xlabel('Total Minutes Asleep')
plt.ylabel('Total Time in Bed')
plt.title('Total Minutes Asleep Vs Total Time in Bed')

# Add colorbar
cbar = plt.colorbar()
cbar.set_label('Total Time in Bed', rotation=90)

# %%
sns.scatterplot(data=merged, x='BMI', y='TotalSteps', hue='BMIRange', style='BMIRange', size='TotalSteps', palette='viridis')

# Set labels and title
plt.xlabel('BMI')
plt.ylabel('Total Steps')
plt.title('BMI Vs Total Steps')

# Show the plot with facets
plt.legend(title='BMIRange')
plt.tight_layout()  # Ensures labels are not cut off
plt.show()

# %%
plt.scatter(x=merged['TotalDistance'],y=merged['TotalSteps'],c=merged['TotalSteps'],cmap='viridis')
plt.xlabel('TotalDistance')
plt.ylabel('TotalSteps')
plt.title('TotalDistance vs TotalSteps')
cbar = plt.colorbar()
cbar.set_label('TotalSteps', rotation=90)

# %%
sns.regplot(data=merged, x='Calories', y=merged['VeryActiveMinutes'] / 60, scatter=False, color='brown', lowess=True)
sns.scatterplot(data=merged, x='Calories', y=merged['VeryActiveMinutes'] / 60, hue='Calories', palette='viridis')
# Out:
# <Axes: xlabel='Calories', ylabel='VeryActiveMinutes'>
